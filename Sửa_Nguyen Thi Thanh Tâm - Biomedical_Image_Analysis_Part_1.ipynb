# %% [markdown]
# <a href="https://colab.research.google.com/github/Serurays/Biomedical_Image_Analysis/blob/main/Biomedical_Image_Analysis_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip "brain_0_volume.zip"
# Out:
# unzip:  cannot find or open brain_0_volume.zip, brain_0_volume.zip.zip or brain_0_volume.zip.ZIP.

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !wget https://github.com/tam0123456789/XL.ANH1/upload/main
# Out:
# --2025-05-12 16:36:32--  https://github.com/tam0123456789/XL.ANH1/upload/main
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘main’
#
# main                    [ <=>                ] 163.30K  --.-KB/s    in 0.05s
#
# 2025-05-12 16:36:33 (3.26 MB/s) - ‘main’ saved [167221]

# %%
import imageio.v2 as imageio
import os

# Get the current working directory
cwd = os.getcwd()

# Construct the path to the image file
# Removed the invalid URL from the path
# image_path = os.path.join(cwd,"https://github.com/tam0123456789/XL.ANH1
# Replace "image.jpg" with the actual path to your image file
image_path = os.path.join(cwd, "brain_0_volume/Testing/pituitary/IMG0080.dcm")

# Check if the file exists
if os.path.exists(image_path):
    img = imageio.imread(image_path)
    print("Type of the image:", type(img))
    print("Shape of the image:", img.shape)
    # The following lines might raise errors depending on the image file format
    #  and whether metadata is available.
    #  You'll need to handle potential KeyError exceptions for missing keys.
    try:
        print("Meta Data of the Image:", img.meta.keys())
        print("Imaging Modality:", img.meta["Modality"])
        print("Patient Name:", img.meta["PatientName"])
        print("Study Date:", img.meta["StudyDate"])
    except (AttributeError, KeyError) as e:
        print(f"Error accessing image metadata: {e}")

else:
    print(f"Error: File not found at {image_path}")
    # Remove the attempt to read the image if it's not found
    # This prevents the FileNotFoundError
# Out:
# Error: File not found at /content/brain_0_volume/Testing/pituitary/IMG0080.dcm

# %%
# !ls /content/brain_0_volume/Testing/pituitary
# Out:
# Te-pi_0010.jpg	Te-pi_0085.jpg	Te-pi_0160.jpg	Te-pi_0235.jpg
# Te-pi_0011.jpg	Te-pi_0086.jpg	Te-pi_0161.jpg	Te-pi_0236.jpg
# Te-pi_0012.jpg	Te-pi_0087.jpg	Te-pi_0162.jpg	Te-pi_0237.jpg
# Te-pi_0013.jpg	Te-pi_0088.jpg	Te-pi_0163.jpg	Te-pi_0238.jpg
# Te-pi_0014.jpg	Te-pi_0089.jpg	Te-pi_0164.jpg	Te-pi_0239.jpg
# Te-pi_0015.jpg	Te-pi_0090.jpg	Te-pi_0165.jpg	Te-pi_0240.jpg
# Te-pi_0016.jpg	Te-pi_0091.jpg	Te-pi_0166.jpg	Te-pi_0241.jpg
# Te-pi_0017.jpg	Te-pi_0092.jpg	Te-pi_0167.jpg	Te-pi_0242.jpg
# Te-pi_0018.jpg	Te-pi_0093.jpg	Te-pi_0168.jpg	Te-pi_0243.jpg
# Te-pi_0019.jpg	Te-pi_0094.jpg	Te-pi_0169.jpg	Te-pi_0244.jpg
# Te-pi_0020.jpg	Te-pi_0095.jpg	Te-pi_0170.jpg	Te-pi_0245.jpg
# Te-pi_0021.jpg	Te-pi_0096.jpg	Te-pi_0171.jpg	Te-pi_0246.jpg
# Te-pi_0079.jpg	Te-pi_0154.jpg	Te-pi_0229.jpg	Te-piTr_0004.jpg
# Te-pi_0080.jpg	Te-pi_0155.jpg	Te-pi_0230.jpg	Te-piTr_0005.jpg
# Te-pi_0081.jpg	Te-pi_0156.jpg	Te-pi_0231.jpg	Te-piTr_0006.jpg
# Te-pi_0082.jpg	Te-pi_0157.jpg	Te-pi_0232.jpg	Te-piTr_0007.jpg
# Te-pi_0083.jpg	Te-pi_0158.jpg	Te-pi_0233.jpg	Te-piTr_0008.jpg
# Te-pi_0084.jpg	Te-pi_0159.jpg	Te-pi_0234.jpg	Te-piTr_0009.jpg

# %%
import imageio.v2 as imageio

img = imageio.imread("/content/brain_0_volume/Testing/IMG0080.dcm")

print("Type of the image:", type(img))

print("Shape of the image:", img.shape)

print("Meta Data of the Image:", img.meta.keys())

print("Imaging Modality:", img.meta["Modality"])

print("Patient Name:", img.meta["PatientName"])

print("Study Date:", img.meta["StudyDate"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-4fb0787a9c7a> in <cell line: 0>()
#       1 import imageio.v2 as imageio
#       2
# ----> 3 img = imageio.imread("/content/brain_0_volume/Testing/IMG0080.dcm")
#       4
#       5 print("Type of the image:", type(img))
#
# /usr/local/lib/python3.11/dist-packages/imageio/v2.py in imread(uri, format, **kwargs)
#     357     imopen_args["legacy_mode"] = True
#     358
# --> 359     with imopen(uri, "ri", **imopen_args) as file:
#     360         result = file.read(index=0, **kwargs)
#     361
#
# /usr/local/lib/python3.11/dist-packages/imageio/core/imopen.py in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111         request.format_hint = format_hint
#     112     else:
# --> 113         request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     114
#     115     source = "<bytes>" if isinstance(uri, bytes) else uri
#
# /usr/local/lib/python3.11/dist-packages/imageio/core/request.py in __init__(self, uri, mode, extension, format_hint, **kwargs)
#     247
#     248         # Parse what was given
# --> 249         self._parse_uri(uri)
#     250
#     251         # Set extension
#
# /usr/local/lib/python3.11/dist-packages/imageio/core/request.py in _parse_uri(self, uri)
#     407                 # Reading: check that the file exists (but is allowed a dir)
#     408                 if not os.path.exists(fn):
# --> 409                     raise FileNotFoundError("No such file: '%s'" % fn)
#     410             else:
#     411                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/content/brain_0_volume/Testing/IMG0080.dcm'

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].imshow(img, cmap="gray")
axes[1].imshow(img, vmin=500, vmax=1000, cmap="gray")

for ax in axes:
  ax.axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b35952cb43c7> in <cell line: 0>()
#       3 fig, axes = plt.subplots(nrows=1, ncols=2)
#       4
# ----> 5 axes[0].imshow(img, cmap="gray")
#       6 axes[1].imshow(img, vmin=500, vmax=1000, cmap="gray")
#       7
#
# NameError: name 'img' is not defined

# %%
import numpy as np

img1 = imageio.imread("/content/brain_0_volume/IMG0080.dcm")
img2 = imageio.imread("/content/brain_0_volume/IMG0081.dcm")
img3 = imageio.imread("/content/brain_0_volume/IMG0082.dcm")

vol = np.stack([img1, img2, img3])

print("Image shape:", img.shape)
print("Volume shape:", vol.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-d4e9f9656e25> in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 img1 = imageio.imread("/content/brain_0_volume/IMG0080.dcm")
#       4 img2 = imageio.imread("/content/brain_0_volume/IMG0081.dcm")
#       5 img3 = imageio.imread("/content/brain_0_volume/IMG0082.dcm")
#
# /usr/local/lib/python3.11/dist-packages/imageio/v2.py in imread(uri, format, **kwargs)
#     357     imopen_args["legacy_mode"] = True
#     358
# --> 359     with imopen(uri, "ri", **imopen_args) as file:
#     360         result = file.read(index=0, **kwargs)
#     361
#
# /usr/local/lib/python3.11/dist-packages/imageio/core/imopen.py in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111         request.format_hint = format_hint
#     112     else:
# --> 113         request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     114
#     115     source = "<bytes>" if isinstance(uri, bytes) else uri
#
# /usr/local/lib/python3.11/dist-packages/imageio/core/request.py in __init__(self, uri, mode, extension, format_hint, **kwargs)
#     247
#     248         # Parse what was given
# --> 249         self._parse_uri(uri)
#     250
#     251         # Set extension
#
# /usr/local/lib/python3.11/dist-packages/imageio/core/request.py in _parse_uri(self, uri)
#     407                 # Reading: check that the file exists (but is allowed a dir)
#     408                 if not os.path.exists(fn):
# --> 409                     raise FileNotFoundError("No such file: '%s'" % fn)
#     410             else:
#     411                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/content/brain_0_volume/IMG0080.dcm'

# %%
import os

os.listdir("brain_0_volume")
# Out:
# ['IMG0122.dcm',
#  'IMG0141.dcm',
#  'IMG0143.dcm',
#  'IMG0103.dcm',
#  'IMG0108.dcm',
#  'IMG0001.dcm',
#  'IMG0079.dcm',
#  'IMG0008.dcm',
#  'IMG0015.dcm',
#  'IMG0023.dcm',
#  'IMG0061.dcm',
#  'IMG0032.dcm',
#  'IMG0012.dcm',
#  'IMG0098.dcm',
#  'IMG0018.dcm',
#  'IMG0059.dcm',
#  'IMG0007.dcm',
#  'IMG0076.dcm',
#  'IMG0024.dcm',
#  'IMG0010.dcm',
#  'IMG0071.dcm',
#  'IMG0041.dcm',
#  'IMG0153.dcm',
#  'IMG0037.dcm',
#  'IMG0005.dcm',
#  'IMG0042.dcm',
#  'IMG0003.dcm',
#  'IMG0100.dcm',
#  'IMG0055.dcm',
#  'IMG0060.dcm',
#  'IMG0094.dcm',
#  'IMG0152.dcm',
#  'IMG0131.dcm',
#  'IMG0026.dcm',
#  'IMG0155.dcm',
#  'IMG0149.dcm',
#  'IMG0150.dcm',
#  'IMG0146.dcm',
#  'IMG0030.dcm',
#  'IMG0009.dcm',
#  'IMG0137.dcm',
#  'IMG0043.dcm',
#  'IMG0028.dcm',
#  'IMG0133.dcm',
#  'IMG0112.dcm',
#  'IMG0022.dcm',
#  'IMG0077.dcm',
#  'IMG0019.dcm',
#  'IMG0113.dcm',
#  'IMG0045.dcm',
#  'IMG0106.dcm',
#  'IMG0011.dcm',
#  'IMG0063.dcm',
#  'IMG0144.dcm',
#  'IMG0074.dcm',
#  'IMG0072.dcm',
#  'IMG0140.dcm',
#  'IMG0099.dcm',
#  'IMG0107.dcm',
#  'IMG0117.dcm',
#  'IMG0020.dcm',
#  'IMG0002.dcm',
#  'IMG0064.dcm',
#  'IMG0040.dcm',
#  'IMG0111.dcm',
#  'IMG0118.dcm',
#  'IMG0151.dcm',
#  'IMG0088.dcm',
#  'IMG0017.dcm',
#  'IMG0054.dcm',
#  'IMG0035.dcm',
#  'IMG0148.dcm',
#  'IMG0119.dcm',
#  'IMG0080.dcm',
#  'IMG0047.dcm',
#  'IMG0086.dcm',
#  'IMG0114.dcm',
#  'IMG0050.dcm',
#  'IMG0046.dcm',
#  'IMG0044.dcm',
#  'IMG0104.dcm',
#  'IMG0025.dcm',
#  'IMG0069.dcm',
#  'IMG0130.dcm',
#  'IMG0085.dcm',
#  'IMG0082.dcm',
#  'IMG0127.dcm',
#  'IMG0084.dcm',
#  'IMG0013.dcm',
#  'IMG0016.dcm',
#  'IMG0038.dcm',
#  'IMG0121.dcm',
#  'IMG0004.dcm',
#  'IMG0154.dcm',
#  'IMG0128.dcm',
#  'IMG0129.dcm',
#  'IMG0139.dcm',
#  'IMG0134.dcm',
#  'IMG0029.dcm',
#  'IMG0142.dcm',
#  'IMG0083.dcm',
#  'IMG0110.dcm',
#  'IMG0027.dcm',
#  'IMG0075.dcm',
#  'IMG0132.dcm',
#  'IMG0090.dcm',
#  'IMG0051.dcm',
#  'IMG0070.dcm',
#  'IMG0126.dcm',
#  'IMG0033.dcm',
#  'IMG0115.dcm',
#  'IMG0068.dcm',
#  'IMG0039.dcm',
#  'IMG0092.dcm',
#  'IMG0096.dcm',
#  'IMG0066.dcm',
#  'IMG0136.dcm',
#  'IMG0124.dcm',
#  'IMG0123.dcm',
#  'IMG0021.dcm',
#  'IMG0014.dcm',
#  'IMG0049.dcm',
#  'IMG0065.dcm',
#  'IMG0078.dcm',
#  'IMG0109.dcm',
#  'IMG0135.dcm',
#  'IMG0091.dcm',
#  'IMG0048.dcm',
#  'IMG0147.dcm',
#  'IMG0031.dcm',
#  'IMG0087.dcm',
#  'IMG0006.dcm',
#  'IMG0073.dcm',
#  'IMG0102.dcm',
#  'IMG0034.dcm',
#  'IMG0095.dcm',
#  'IMG0057.dcm',
#  'IMG0058.dcm',
#  'IMG0067.dcm',
#  'IMG0089.dcm',
#  'IMG0145.dcm',
#  'IMG0138.dcm',
#  'IMG0116.dcm',
#  'IMG0125.dcm',
#  'IMG0062.dcm',
#  'IMG0053.dcm',
#  'IMG0052.dcm',
#  'IMG0097.dcm',
#  'IMG0056.dcm',
#  'IMG0105.dcm',
#  'IMG0101.dcm',
#  'IMG0093.dcm',
#  'IMG0120.dcm',
#  'IMG0036.dcm',
#  'IMG0081.dcm']

# %%
vol = imageio.volread(uri="brain_0_volume", format="DICOM")

vol.shape
# Out:
# 155/155 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 155/155  (100.0%)
# (155, 240, 240)

# %%
n0, n1, n2 = vol.shape
d0, d1, d2 = vol.meta["sampling"]
n0 * d0, n1 * d1, n2 * d2
# Out:
# (155.0, 240.0, 240.0)

# %%
d0, d1, d2 = vol.meta["sampling"]
d0, d1, d2
# Out:
# (1.0, 1.0, 1.0)

# %%
view_axial = vol[80, :, :]
view_coronal = vol[:, 80, :]
view_sagittal = vol[:, :, 80]

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 6))

axes[0].imshow(view_axial, cmap="gray", vmin=-200, vmax=200)
axes[0].set_title("Axial View of the 80th Slice")
axes[1].imshow(view_coronal, cmap="gray", vmin=-200, vmax=200)
axes[1].set_title("Coronal View of the 80th Slice")
axes[2].imshow(view_sagittal, cmap="gray", vmin=-200, vmax=200)
axes[2].set_title("Sagittal View of the 80th Slice")

for ax in axes:
  ax.axis("off")

plt.show()

# %%
img1 = vol[:, 80, :]
img2 = vol[:, :, 80]

d0, d1, d2 = vol.meta["sampling"]

asp1 = d0 / d2
asp2 = d0 / d1

fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].imshow(img1, cmap="gray", aspect=asp1)
axes[1].imshow(img2, cmap="gray", aspect=asp2)

for ax in axes:
  ax.axis("off")

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=4)

for i in range(4):
  img = vol[i*40, :, :]
  axes[i].imshow(img, cmap="gray")
  axes[i].axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-049b136350de> in <cell line: 0>()
# ----> 1 fig, axes = plt.subplots(nrows=1, ncols=4)
#       2
#       3 for i in range(4):
#       4   img = vol[i*40, :, :]
#       5   axes[i].imshow(img, cmap="gray")
#
# NameError: name 'plt' is not defined
